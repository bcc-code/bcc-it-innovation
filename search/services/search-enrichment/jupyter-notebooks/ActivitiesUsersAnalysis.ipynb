# %%
import pandas as pd

activities = pd.read_csv('../data/activities.csv')
registrations = pd.read_csv('../data/registrations.csv')
users = pd.read_csv("../data/users.csv")
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (62,71,76,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
activities
# Out:
#        ActivityId                                        Description  \
# 0           25666  - rydde vindfall, ta med motorsag\r\n- rydde s...
# 1           25722  - rydde vindfall, ta med sag\r\n- rydde i hall...
# 2           27089  <p>\r\n Innbetalinger Drift for Februar 2012</...
# 3           27260         Assembling Ikea furniture paid at £10/hour
# 4           27264  This is for cleaning of Huntworth for SSL not ...
# ...           ...                                                ...
# 23820      381695                                                NaN
# 23821      381696  <p>Malen im Saal</p>\n\n<p>&nbsp;</p>\n\n<p>TL...
# 23822      381697  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23823      381698  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23824      381699                                                NaN
#
#                              Start                       Finish  \
# 0      2012-02-04 10:00:00.0000000  2012-02-04 15:00:00.0000000
# 1      2012-02-04 10:00:00.0000000  2012-02-04 15:00:00.0000000
# 2      2012-02-29 21:00:00.0000000  2012-02-29 22:00:00.0000000
# 3      2012-03-06 17:00:00.0000000  2012-03-06 19:00:00.0000000
# 4      2012-01-04 00:00:00.0000000  2012-03-06 19:00:00.0000000
# ...                            ...                          ...
# 23820  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23821  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23822  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23823  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23824  2021-07-08 17:00:00.0000000  2021-07-08 19:00:00.0000000
#
#                                      Name  ResponsibleUserId  \
# 0                   Dugnad på Mordalsmyra              16505
# 1                   Dugnad på Mordalsmyra              16505
# 2      Innbetalinger DRIFT - Februar 2012              13501
# 3           13 Durleigh Road Ikea Project              25024
# 4                                Cleaning              16098
# ...                                   ...                ...
# 23820               Personalpool / Backup              21004
# 23821                               Malen              22296
# 23822                           Spachteln              24351
# 23823                           Spachteln              24351
# 23824                        import 07/21                  0
#
#        ResponsibleRegistrationNotification  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 23820                                  0.0
# 23821                                  0.0
# 23822                                  0.0
# 23823                                  0.0
# 23824                                  0.0
#
#        ResponsibleUnregistrationNotification  TypeId  NeededParticipants  ...  \
# 0                                        NaN     135                  15  ...
# 1                                        NaN     137                  10  ...
# 2                                        NaN     135                   0  ...
# 3                                        NaN       5                   4  ...
# 4                                        NaN       5                   0  ...
# ...                                      ...     ...                 ...  ...
# 23820                                    0.0       5                  35  ...
# 23821                                    0.0     137                  10  ...
# 23822                                    0.0     137                  10  ...
# 23823                                    0.0     137                  10  ...
# 23824                                    0.0     135                   0  ...
#
#       RegistrationRestrictions  CustomFields  \
# 0                          NaN           NaN
# 1                          NaN           NaN
# 2                          NaN           NaN
# 3                          NaN           NaN
# 4                          NaN           NaN
# ...                        ...           ...
# 23820                      NaN            {}
# 23821                      NaN            {}
# 23822                      NaN            {}
# 23823                      NaN            {}
# 23824                      NaN            {}
#
#        UsersAllowedToRegisterOutsideAgeOrGenderLimitations  OwnerGroup  \
# 0                                                    NaN             0
# 1                                                    NaN             0
# 2                                                    NaN             0
# 3                                                    NaN             0
# 4                                                    NaN             0
# ...                                                  ...           ...
# 23820                                                NaN             0
# 23821                                                NaN         -1546
# 23822                                                NaN         -1546
# 23823                                                NaN         -1546
# 23824                                                NaN             0
#
#        RegistrationEnd  ClockingTerminalRoundingPrecision  \
# 0                  NaN                                  0
# 1                  NaN                                  0
# 2                  NaN                                  0
# 3                  NaN                                  0
# 4                  NaN                                  0
# ...                ...                                ...
# 23820              NaN                                  0
# 23821              NaN                                  0
# 23822              NaN                                  0
# 23823              NaN                                  0
# 23824              NaN                                  0
#
#        ClockingTerminalDefaultPause NoCollisionCheck  HideNumRegistrations  \
# 0                                 0              NaN                   NaN
# 1                                 0              NaN                   NaN
# 2                                 0              NaN                   NaN
# 3                                 0              NaN                   NaN
# 4                                 0              NaN                   NaN
# ...                             ...              ...                   ...
# 23820                             0              NaN                   NaN
# 23821                             0              NaN                   NaN
# 23822                             0              NaN                   NaN
# 23823                             0              NaN                   NaN
# 23824                             0              0.0                   0.0
#
#                                ActivityGUID
# 0      E1424A82-53EF-4D73-9BF8-14A904F317F8
# 1      F1406B04-64B3-44C6-9B22-93DC28AFA35A
# 2      460DAC84-E1CB-42D4-B54B-87736FA943A9
# 3      3EC496DC-FAA1-4A09-B396-5647A5AE1434
# 4      E6054AF3-2644-4286-966E-537FF0FA446A
# ...                                     ...
# 23820  00000000-0000-0000-0000-000000000000
# 23821  00000000-0000-0000-0000-000000000000
# 23822  00000000-0000-0000-0000-000000000000
# 23823  00000000-0000-0000-0000-000000000000
# 23824  00000000-0000-0000-0000-000000000000
#
# [23825 rows x 84 columns]

# %%
activitiesIn2021 = activities[activities['Start'] > '2021-01-01']

# %%
activitiesIn2021
# Out:
#        ActivityId                                        Description  \
# 11603      332578  <p>Ringevakt Rema 1000- m&aring; v&aelig;re kj...
# 12532      345940                                                NaN
# 13286      360029  <p>Welkom op de Bavinckel tijdens de nationale...
# 13436      362679                                                NaN
# 13437      362680                                                NaN
# ...           ...                                                ...
# 23820      381695                                                NaN
# 23821      381696  <p>Malen im Saal</p>\n\n<p>&nbsp;</p>\n\n<p>TL...
# 23822      381697  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23823      381698  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23824      381699                                                NaN
#
#                              Start                       Finish  \
# 11603  2021-08-24 12:00:00.0000000  2021-08-24 18:00:00.0000000
# 12532  2021-10-05 17:00:00.0000000  2021-10-15 17:00:00.0000000
# 13286  2021-02-27 08:00:00.0000000  2021-02-27 12:30:00.0000000
# 13436  2021-03-03 19:00:00.0000000  2021-03-03 19:00:00.0000000
# 13437  2021-04-04 19:00:00.0000000  2021-04-04 19:00:00.0000000
# ...                            ...                          ...
# 23820  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23821  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23822  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23823  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23824  2021-07-08 17:00:00.0000000  2021-07-08 19:00:00.0000000
#
#                          Name  ResponsibleUserId  \
# 11603               Ringevakt              18259
# 12532  Jugendtour Israel 2021              22488
# 13286               Onderhoud              23648
# 13436                 Diverse              24207
# 13437                 Diverse              24207
# ...                       ...                ...
# 23820   Personalpool / Backup              21004
# 23821                   Malen              22296
# 23822               Spachteln              24351
# 23823               Spachteln              24351
# 23824            import 07/21                  0
#
#        ResponsibleRegistrationNotification  \
# 11603                                  0.0
# 12532                                  0.0
# 13286                                  2.0
# 13436                                  0.0
# 13437                                  0.0
# ...                                    ...
# 23820                                  0.0
# 23821                                  0.0
# 23822                                  0.0
# 23823                                  0.0
# 23824                                  0.0
#
#        ResponsibleUnregistrationNotification  TypeId  NeededParticipants  ...  \
# 11603                                    0.0       5                   2  ...
# 12532                                    0.0     139                   0  ...
# 13286                                    2.0     137                  10  ...
# 13436                                    0.0       5                   0  ...
# 13437                                    0.0       5                   0  ...
# ...                                      ...     ...                 ...  ...
# 23820                                    0.0       5                  35  ...
# 23821                                    0.0     137                  10  ...
# 23822                                    0.0     137                  10  ...
# 23823                                    0.0     137                  10  ...
# 23824                                    0.0     135                   0  ...
#
#       RegistrationRestrictions  CustomFields  \
# 11603                      NaN            {}
# 12532                      NaN            {}
# 13286                      NaN            {}
# 13436                      NaN            {}
# 13437                      NaN            {}
# ...                        ...           ...
# 23820                      NaN            {}
# 23821                      NaN            {}
# 23822                      NaN            {}
# 23823                      NaN            {}
# 23824                      NaN            {}
#
#        UsersAllowedToRegisterOutsideAgeOrGenderLimitations  OwnerGroup  \
# 11603                                                NaN             0
# 12532                                                NaN             0
# 13286                                                NaN             0
# 13436                                                NaN          3956
# 13437                                                NaN          3956
# ...                                                  ...           ...
# 23820                                                NaN             0
# 23821                                                NaN         -1546
# 23822                                                NaN         -1546
# 23823                                                NaN         -1546
# 23824                                                NaN             0
#
#        RegistrationEnd  ClockingTerminalRoundingPrecision  \
# 11603              NaN                                  0
# 12532              NaN                                  0
# 13286              NaN                                  0
# 13436              NaN                                  0
# 13437              NaN                                  0
# ...                ...                                ...
# 23820              NaN                                  0
# 23821              NaN                                  0
# 23822              NaN                                  0
# 23823              NaN                                  0
# 23824              NaN                                  0
#
#        ClockingTerminalDefaultPause NoCollisionCheck  HideNumRegistrations  \
# 11603                             0              NaN                   NaN
# 12532                             0              NaN                   NaN
# 13286                             0              NaN                   NaN
# 13436                             0              NaN                   NaN
# 13437                             0              NaN                   NaN
# ...                             ...              ...                   ...
# 23820                             0              NaN                   NaN
# 23821                             0              NaN                   NaN
# 23822                             0              NaN                   NaN
# 23823                             0              NaN                   NaN
# 23824                             0              0.0                   0.0
#
#                                ActivityGUID
# 11603  38891487-0D76-4225-8E54-5022B8A25B7B
# 12532  DB093D13-1158-408B-9122-4D955910AAF6
# 13286  C16B47C9-2888-4F06-B5A6-5E44E1D0D55D
# 13436  E40F01E0-2226-400D-93B3-BC7878C527B3
# 13437  535A75CB-A0FC-4DD4-9549-52671A54B7E4
# ...                                     ...
# 23820  00000000-0000-0000-0000-000000000000
# 23821  00000000-0000-0000-0000-000000000000
# 23822  00000000-0000-0000-0000-000000000000
# 23823  00000000-0000-0000-0000-000000000000
# 23824  00000000-0000-0000-0000-000000000000
#
# [10134 rows x 84 columns]

# %%
from collections import Counter

Counter(" ".join(map(str, activitiesIn2021["Description"])).split()).most_common(100)
# Out:
# [('nan', 5574),
#  ('og', 2895),
#  ('<p>-', 2254),
#  ('/>', 1654),
#  ('med', 1630),
#  ('p&aring;', 1294),
#  ('til', 1288),
#  ('<p>&nbsp;</p>', 1138),
#  ('i', 1071),
#  ('&nbsp;', 1064),
#  ('for', 890),
#  ('er', 889),
#  ('the', 847),
#  ('m&aring;', 799),
#  ('skal', 700),
#  ('av', 669),
#  ('du', 603),
#  ('bruke', 594),
#  ('and', 555),
#  ('&aring;', 528),
#  ('in', 501),
#  ('at', 461),
#  ('-', 423),
#  ('alle', 416),
#  ('om', 398),
#  ('egen', 377),
#  ('</ul>', 377),
#  ('en', 372),
#  ('det', 366),
#  ('ogs&aring;', 365),
#  ('<p>Alle', 355),
#  ('kan', 354),
#  ('<p>Husk', 334),
#  ('vernesko', 332),
#  ('b&aring;de', 330),
#  ('deg', 320),
#  ('munnbind', 318),
#  ('</li>', 310),
#  ('to', 305),
#  ('man', 302),
#  ('ute', 299),
#  ('ikke', 291),
#  ('byggeplassen,', 288),
#  ('Husk', 285),
#  ('of', 282),
#  ('&amp;', 280),
#  ('be', 278),
#  ('refleksvest/synlighetskl&aelig;r,', 274),
#  ('Ta', 273),
#  ('mat', 268),
#  ('inne', 267),
#  ('l&oslash;rdag', 255),
#  ('<li>', 250),
#  ('<p>Dugnad', 250),
#  ('som', 249),
#  ('hverdag', 245),
#  ('18-21.30', 245),
#  ('(kaffe/saft', 245),
#  ('09.00-16.00', 245),
#  ('(lunsj', 245),
#  ('<ul>', 243),
#  ('all', 233),
#  ('Alle', 230),
#  ('denne', 230),
#  ('2', 228),
#  ('<p>Medbring', 228),
#  ('blir', 225),
#  ('1', 223),
#  ('hvis', 223),
#  ('a', 222),
#  ('seg', 218),
#  ('ha', 218),
#  ('<p>1', 217),
#  ('PSI', 217),
#  ('<br', 215),
#  ('Hold', 212),
#  ('sammen', 206),
#  ('drikke', 201),
#  ('12.00-12.45)</p>', 201),
#  ('but', 199),
#  ('n&aring;r', 199),
#  ('arbeider', 197),
#  ('Dugnad', 196),
#  ('up', 194),
#  ('20.00-20.15).', 193),
#  ('kr', 190),
#  ('is', 188),
#  ('god', 186),
#  ('hjelm.</p>', 184),
#  ('with', 182),
#  ('Oslofjord', 179),
#  ('Convention', 179),
#  ('</td>', 177),
#  ('ta', 175),
#  ('fra', 173),
#  ('HMS', 173),
#  ('time', 169),
#  ('clean', 168),
#  ('<p>Ta', 163),
#  ('<p>o&nbsp;Alle', 162)]

# %%
activitiesIn2021['Description'] = activitiesIn2021['Description'].astype(str)
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def parser(text):
    return re.sub('<[^<]+?>', '', str(text))

result=activitiesIn2021['Description'].apply(parser)

# %%
result
# Out:
# 11603    Ringevakt Rema 1000- m&aring; v&aelig;re kjent...
# 12532                                                  nan
# 13286    Welkom op de Bavinckel tijdens de nationale ac...
# 13436                                                  nan
# 13437                                                  nan
#                                ...
# 23820                                                  nan
# 23821       Malen im Saal\n\n&nbsp;\n\nTL: Marit Nielsen\n
# 23822     Spachteln im Saal\n\n&nbsp;\n\nTL: Sina Tobler\n
# 23823     Spachteln im Saal\n\n&nbsp;\n\nTL: Sina Tobler\n
# 23824                                                  nan
# Name: Description, Length: 10134, dtype: object

# %%
from collections import Counter

Counter(" ".join(map(str, result)).split()).most_common(100)
# Out:
# [('nan', 5574),
#  ('og', 2965),
#  ('-', 2701),
#  ('&nbsp;', 2271),
#  ('med', 1630),
#  ('p&aring;', 1294),
#  ('til', 1289),
#  ('i', 1071),
#  ('for', 890),
#  ('er', 889),
#  ('the', 847),
#  ('m&aring;', 799),
#  ('skal', 700),
#  ('av', 669),
#  ('Alle', 633),
#  ('Husk', 619),
#  ('du', 603),
#  ('bruke', 594),
#  ('and', 556),
#  ('&aring;', 528),
#  ('in', 502),
#  ('Ta', 473),
#  ('at', 461),
#  ('1', 455),
#  ('Dugnad', 446),
#  ('vernesko', 441),
#  ('alle', 416),
#  ('om', 398),
#  ('egen', 377),
#  ('en', 373),
#  ('det', 367),
#  ('ogs&aring;', 365),
#  ('2', 362),
#  ('kan', 354),
#  ('b&aring;de', 330),
#  ('munnbind', 322),
#  ('Det', 321),
#  ('deg', 320),
#  ('to', 305),
#  ('man', 302),
#  ('ute', 299),
#  ('clean', 291),
#  ('ikke', 291),
#  ('byggeplassen,', 288),
#  ('of', 282),
#  ('&amp;', 280),
#  ('be', 278),
#  ('refleksvest/synlighetskl&aelig;r,', 274),
#  ('inne', 269),
#  ('mat', 268),
#  ('l&oslash;rdag', 255),
#  ('som', 249),
#  ('hverdag', 245),
#  ('18-21.30', 245),
#  ('(kaffe/saft', 245),
#  ('09.00-16.00', 245),
#  ('(lunsj', 245),
#  ('up', 242),
#  ('all', 233),
#  ('Vi', 231),
#  ('denne', 230),
#  ('Medbring', 228),
#  ('blir', 225),
#  ('hvis', 223),
#  ('a', 222),
#  ('PSI', 220),
#  ('seg', 218),
#  ('ha', 218),
#  ('drikke', 216),
#  ('hjelm.', 216),
#  ('Hold', 212),
#  ('sammen', 206),
#  ('12.00-12.45)', 201),
#  ('bins', 200),
#  ('but', 199),
#  ('n&aring;r', 199),
#  ('HMS', 198),
#  ('arbeider', 197),
#  ('Oppm&oslash;te', 196),
#  ('kr', 193),
#  ('20.00-20.15).', 193),
#  ('is', 188),
#  ('god', 186),
#  ('with', 182),
#  ('time', 179),
#  ('Oslofjord', 179),
#  ('Convention', 179),
#  ('ta', 177),
#  ('BUK', 176),
#  ('area', 174),
#  ('fra', 173),
#  ('cleaning', 171),
#  ('3', 169),
#  ('hall', 166),
#  ('Center.', 165),
#  ('4', 163),
#  ('har', 162),
#  ('ensure', 162),
#  ('o&nbsp;Alle', 162),
#  ('w', 159)]

# %%
from collections import Counter

Counter(" ".join(map(str, activitiesIn2021["Name"])).split()).most_common(100)
# Out:
# [('/', 1002),
#  ('Diverse', 602),
#  ('Cleaning', 427),
#  ('Haugen', 340),
#  ('-', 303),
#  ('Bidrag', 303),
#  ('Coffee', 297),
#  ('U18', 247),
#  ('Renhold', 241),
#  ('Team', 236),
#  ('Vedlikehold', 219),
#  ('bar', 199),
#  ('Annet', 196),
#  ('Clean', 196),
#  ('og', 186),
#  ('tømrer', 184),
#  ('O18', 183),
#  ('Maling', 181),
#  ('Snekker', 181),
#  ('up', 177),
#  ('Mawarra', 175),
#  ('Jernholmen', 167),
#  ('Utomhus', 159),
#  ('Pakking', 154),
#  ('Rydding', 151),
#  ('Tømrer', 139),
#  ('Kitchen', 132),
#  ('🔥', 130),
#  ('and', 128),
#  ('Rigg', 123),
#  ('ANM', 123),
#  ('Reinigung', 121),
#  ('Produksjon', 119),
#  ('Stand', 104),
#  ('Concession', 103),
#  ('Byggvask', 100),
#  ('Meeting', 97),
#  ('Shop', 97),
#  ('Work', 92),
#  ('Tuckshop', 91),
#  ('AOI', 89),
#  ('Chicken', 86),
#  ('catching', 86),
#  ('BUK', 83),
#  ('Veddugnad', 81),
#  ('Bygging', 81),
#  ('drift', 81),
#  ('Verschiedenes', 78),
#  ('Elektro', 77),
#  ('1', 77),
#  ('Maintenance', 76),
#  ('Shift', 73),
#  ('Rengøring', 72),
#  ('Inventur', 68),
#  ('&', 68),
#  ('Payment', 66),
#  ('Drift', 65),
#  ('Grounds', 65),
#  ('Riving', 64),
#  ('dagtid', 64),
#  ('2', 62),
#  ('BYC', 60),
#  ('Anleggsarbeid', 59),
#  ('som', 59),
#  ('party', 58),
#  ('EC', 58),
#  ('Vasking', 58),
#  ('Alle', 58),
#  ('Food', 57),
#  ('Construction', 57),
#  ('Servering', 57),
#  ('Dishwashing', 56),
#  ('Käteinen', 56),
#  ('maksu', 56),
#  ('|', 56),
#  ('Montering', 55),
#  ('Sprzątanie', 53),
#  ('sobotorobota', 53),
#  ('Personalpool', 52),
#  ('Backup', 52),
#  ('Hire', 50),
#  ('kan', 50),
#  ('Produktion', 48),
#  ('–', 48),
#  ('Vakt', 48),
#  ('3213', 45),
#  ('Rigging', 45),
#  ('Verpflegung', 44),
#  ('BUK:', 44),
#  ('Landscaping', 44),
#  ('Küche', 43),
#  ('Essen', 43),
#  ('Salg', 43),
#  ('preparation', 42),
#  ('Sekatyöt', 42),
#  ('Lower', 42),
#  ('Level', 42),
#  ('4', 42),
#  ('kontor', 41),
#  ('økonomi', 41)]

# %%
activitiesIn2021

# %%
#correlation between description and name
activitiesIn2021["Name"]
activitiesIn2021["Description"]

# %%
activitiesIn2021GroupedByNeededParticipant = activitiesIn2021.groupby(by=["NeededParticipants"], dropna=False).count().reset_index();

# %%
activitiesIn2021
# Out:
#        ActivityId                                        Description  \
# 11603      332578  <p>Ringevakt Rema 1000- m&aring; v&aelig;re kj...
# 12532      345940                                                NaN
# 13286      360029  <p>Welkom op de Bavinckel tijdens de nationale...
# 13436      362679                                                NaN
# 13437      362680                                                NaN
# ...           ...                                                ...
# 23820      381695                                                NaN
# 23821      381696  <p>Malen im Saal</p>\n\n<p>&nbsp;</p>\n\n<p>TL...
# 23822      381697  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23823      381698  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23824      381699                                                NaN
#
#                              Start                       Finish  \
# 11603  2021-08-24 12:00:00.0000000  2021-08-24 18:00:00.0000000
# 12532  2021-10-05 17:00:00.0000000  2021-10-15 17:00:00.0000000
# 13286  2021-02-27 08:00:00.0000000  2021-02-27 12:30:00.0000000
# 13436  2021-03-03 19:00:00.0000000  2021-03-03 19:00:00.0000000
# 13437  2021-04-04 19:00:00.0000000  2021-04-04 19:00:00.0000000
# ...                            ...                          ...
# 23820  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23821  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23822  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23823  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23824  2021-07-08 17:00:00.0000000  2021-07-08 19:00:00.0000000
#
#                          Name  ResponsibleUserId  \
# 11603               Ringevakt              18259
# 12532  Jugendtour Israel 2021              22488
# 13286               Onderhoud              23648
# 13436                 Diverse              24207
# 13437                 Diverse              24207
# ...                       ...                ...
# 23820   Personalpool / Backup              21004
# 23821                   Malen              22296
# 23822               Spachteln              24351
# 23823               Spachteln              24351
# 23824            import 07/21                  0
#
#        ResponsibleRegistrationNotification  \
# 11603                                  0.0
# 12532                                  0.0
# 13286                                  2.0
# 13436                                  0.0
# 13437                                  0.0
# ...                                    ...
# 23820                                  0.0
# 23821                                  0.0
# 23822                                  0.0
# 23823                                  0.0
# 23824                                  0.0
#
#        ResponsibleUnregistrationNotification  TypeId  NeededParticipants  ...  \
# 11603                                    0.0       5                   2  ...
# 12532                                    0.0     139                   0  ...
# 13286                                    2.0     137                  10  ...
# 13436                                    0.0       5                   0  ...
# 13437                                    0.0       5                   0  ...
# ...                                      ...     ...                 ...  ...
# 23820                                    0.0       5                  35  ...
# 23821                                    0.0     137                  10  ...
# 23822                                    0.0     137                  10  ...
# 23823                                    0.0     137                  10  ...
# 23824                                    0.0     135                   0  ...
#
#       RegistrationRestrictions  CustomFields  \
# 11603                      NaN            {}
# 12532                      NaN            {}
# 13286                      NaN            {}
# 13436                      NaN            {}
# 13437                      NaN            {}
# ...                        ...           ...
# 23820                      NaN            {}
# 23821                      NaN            {}
# 23822                      NaN            {}
# 23823                      NaN            {}
# 23824                      NaN            {}
#
#        UsersAllowedToRegisterOutsideAgeOrGenderLimitations  OwnerGroup  \
# 11603                                                NaN             0
# 12532                                                NaN             0
# 13286                                                NaN             0
# 13436                                                NaN          3956
# 13437                                                NaN          3956
# ...                                                  ...           ...
# 23820                                                NaN             0
# 23821                                                NaN         -1546
# 23822                                                NaN         -1546
# 23823                                                NaN         -1546
# 23824                                                NaN             0
#
#        RegistrationEnd  ClockingTerminalRoundingPrecision  \
# 11603              NaN                                  0
# 12532              NaN                                  0
# 13286              NaN                                  0
# 13436              NaN                                  0
# 13437              NaN                                  0
# ...                ...                                ...
# 23820              NaN                                  0
# 23821              NaN                                  0
# 23822              NaN                                  0
# 23823              NaN                                  0
# 23824              NaN                                  0
#
#        ClockingTerminalDefaultPause NoCollisionCheck  HideNumRegistrations  \
# 11603                             0              NaN                   NaN
# 12532                             0              NaN                   NaN
# 13286                             0              NaN                   NaN
# 13436                             0              NaN                   NaN
# 13437                             0              NaN                   NaN
# ...                             ...              ...                   ...
# 23820                             0              NaN                   NaN
# 23821                             0              NaN                   NaN
# 23822                             0              NaN                   NaN
# 23823                             0              NaN                   NaN
# 23824                             0              0.0                   0.0
#
#                                ActivityGUID
# 11603  38891487-0D76-4225-8E54-5022B8A25B7B
# 12532  DB093D13-1158-408B-9122-4D955910AAF6
# 13286  C16B47C9-2888-4F06-B5A6-5E44E1D0D55D
# 13436  E40F01E0-2226-400D-93B3-BC7878C527B3
# 13437  535A75CB-A0FC-4DD4-9549-52671A54B7E4
# ...                                     ...
# 23820  00000000-0000-0000-0000-000000000000
# 23821  00000000-0000-0000-0000-000000000000
# 23822  00000000-0000-0000-0000-000000000000
# 23823  00000000-0000-0000-0000-000000000000
# 23824  00000000-0000-0000-0000-000000000000
#
# [10134 rows x 84 columns]

# %%
activities['NeededParticipants'].plot().area(figsize=(20, 12), subplots=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-6b8acb04d815> in <module>
# ----> 1 activities['NeededParticipants'].plot().area(figsize=(20, 12), subplots=True)
#
# AttributeError: 'AxesSubplot' object has no attribute 'area'

# %%
activitiesIn2021['NeededParticipants'].plot().area(figsize=(20, 12), subplots=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-c0a9ff22adf6> in <module>
# ----> 1 activitiesIn2021['NeededParticipants'].plot().area(figsize=(20, 12), subplots=True)
#
# AttributeError: 'AxesSubplot' object has no attribute 'area'

# %%
#adding random rating
import random
activitiesIn2021['Rating'] = random.randint(1,5)
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
activitiesIn2021['Rating']
# Out:
# 11603    2
# 12532    2
# 13286    2
# 13436    2
# 13437    2
#         ..
# 23820    2
# 23821    2
# 23822    2
# 23823    2
# 23824    2
# Name: Rating, Length: 10134, dtype: int64

# %%
import numpy as np
activitiesIn2021['Rating'] = np.random.randint(1, 6, activitiesIn2021.shape[0])
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
activitiesIn2021
# Out:
#        ActivityId                                        Description  \
# 11603      332578  <p>Ringevakt Rema 1000- m&aring; v&aelig;re kj...
# 12532      345940                                                NaN
# 13286      360029  <p>Welkom op de Bavinckel tijdens de nationale...
# 13436      362679                                                NaN
# 13437      362680                                                NaN
# ...           ...                                                ...
# 23820      381695                                                NaN
# 23821      381696  <p>Malen im Saal</p>\n\n<p>&nbsp;</p>\n\n<p>TL...
# 23822      381697  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23823      381698  <p>Spachteln im Saal</p>\n\n<p>&nbsp;</p>\n\n<...
# 23824      381699                                                NaN
#
#                              Start                       Finish  \
# 11603  2021-08-24 12:00:00.0000000  2021-08-24 18:00:00.0000000
# 12532  2021-10-05 17:00:00.0000000  2021-10-15 17:00:00.0000000
# 13286  2021-02-27 08:00:00.0000000  2021-02-27 12:30:00.0000000
# 13436  2021-03-03 19:00:00.0000000  2021-03-03 19:00:00.0000000
# 13437  2021-04-04 19:00:00.0000000  2021-04-04 19:00:00.0000000
# ...                            ...                          ...
# 23820  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23821  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23822  2021-07-09 19:00:00.0000000  2021-07-09 22:00:00.0000000
# 23823  2021-07-10 09:00:00.0000000  2021-07-10 15:00:00.0000000
# 23824  2021-07-08 17:00:00.0000000  2021-07-08 19:00:00.0000000
#
#                          Name  ResponsibleUserId  \
# 11603               Ringevakt              18259
# 12532  Jugendtour Israel 2021              22488
# 13286               Onderhoud              23648
# 13436                 Diverse              24207
# 13437                 Diverse              24207
# ...                       ...                ...
# 23820   Personalpool / Backup              21004
# 23821                   Malen              22296
# 23822               Spachteln              24351
# 23823               Spachteln              24351
# 23824            import 07/21                  0
#
#        ResponsibleRegistrationNotification  \
# 11603                                  0.0
# 12532                                  0.0
# 13286                                  2.0
# 13436                                  0.0
# 13437                                  0.0
# ...                                    ...
# 23820                                  0.0
# 23821                                  0.0
# 23822                                  0.0
# 23823                                  0.0
# 23824                                  0.0
#
#        ResponsibleUnregistrationNotification  TypeId  NeededParticipants  ...  \
# 11603                                    0.0       5                   2  ...
# 12532                                    0.0     139                   0  ...
# 13286                                    2.0     137                  10  ...
# 13436                                    0.0       5                   0  ...
# 13437                                    0.0       5                   0  ...
# ...                                      ...     ...                 ...  ...
# 23820                                    0.0       5                  35  ...
# 23821                                    0.0     137                  10  ...
# 23822                                    0.0     137                  10  ...
# 23823                                    0.0     137                  10  ...
# 23824                                    0.0     135                   0  ...
#
#       CustomFields  UsersAllowedToRegisterOutsideAgeOrGenderLimitations  \
# 11603           {}                                                NaN
# 12532           {}                                                NaN
# 13286           {}                                                NaN
# 13436           {}                                                NaN
# 13437           {}                                                NaN
# ...            ...                                                ...
# 23820           {}                                                NaN
# 23821           {}                                                NaN
# 23822           {}                                                NaN
# 23823           {}                                                NaN
# 23824           {}                                                NaN
#
#        OwnerGroup  RegistrationEnd  ClockingTerminalRoundingPrecision  \
# 11603           0              NaN                                  0
# 12532           0              NaN                                  0
# 13286           0              NaN                                  0
# 13436        3956              NaN                                  0
# 13437        3956              NaN                                  0
# ...           ...              ...                                ...
# 23820           0              NaN                                  0
# 23821       -1546              NaN                                  0
# 23822       -1546              NaN                                  0
# 23823       -1546              NaN                                  0
# 23824           0              NaN                                  0
#
#        ClockingTerminalDefaultPause  NoCollisionCheck HideNumRegistrations  \
# 11603                             0               NaN                  NaN
# 12532                             0               NaN                  NaN
# 13286                             0               NaN                  NaN
# 13436                             0               NaN                  NaN
# 13437                             0               NaN                  NaN
# ...                             ...               ...                  ...
# 23820                             0               NaN                  NaN
# 23821                             0               NaN                  NaN
# 23822                             0               NaN                  NaN
# 23823                             0               NaN                  NaN
# 23824                             0               0.0                  0.0
#
#                                ActivityGUID Rating
# 11603  38891487-0D76-4225-8E54-5022B8A25B7B      3
# 12532  DB093D13-1158-408B-9122-4D955910AAF6      1
# 13286  C16B47C9-2888-4F06-B5A6-5E44E1D0D55D      4
# 13436  E40F01E0-2226-400D-93B3-BC7878C527B3      5
# 13437  535A75CB-A0FC-4DD4-9549-52671A54B7E4      5
# ...                                     ...    ...
# 23820  00000000-0000-0000-0000-000000000000      3
# 23821  00000000-0000-0000-0000-000000000000      1
# 23822  00000000-0000-0000-0000-000000000000      5
# 23823  00000000-0000-0000-0000-000000000000      3
# 23824  00000000-0000-0000-0000-000000000000      4
#
# [10134 rows x 85 columns]

# %%
users
# Out:
#        UserId  SourceOrganizationId                      Address1 Address2  \
# 0       10001                  42.0            Joh. Solliesgt 36B      NaN
# 1       10002                  42.0                  Knutsrødv 31      NaN
# 2       10003                  42.0                  Rustadgt. 53      NaN
# 3       10005                  42.0  Inger Alver Gløersens vei 69      NaN
# 4       10006                  42.0              Apenesbakken 18b      NaN
# ...       ...                   ...                           ...      ...
# 31578   55027                  78.0                           NaN      NaN
# 31579   55028                 102.0              6997 e us hwy 36      NaN
# 31580   55029                 102.0             1559 S Dugan Road      NaN
# 31581   55030                  69.0                Molvikveien 64      NaN
# 31582   55031                   7.0          Nedre Fiksnesvika 10      NaN
#
#                               Email            LastName  FamilyId FirstName  \
# 0                     olafa@c2i.net            Andersen     10001      Olaf
# 1        thorandersen0511@gmail.com            Andersen     10002      Thor
# 2                  arilan@online.no            Andersen     10003     Arild
# 3      svein.bernhardsen@sf-nett.no         Bernhardsen     10005     Svein
# 4               ragn1931@icloud.com           Eilertsen     10006  Ragnhild
# ...                             ...                 ...       ...       ...
# 31578                           NaN  Hagen Ingebrigtsen     54999    Henrik
# 31579                           NaN              Hamren     43109      Clay
# 31580                           NaN                Fenn     55029    Averie
# 31581                           NaN             Zürcher     22191     Nelia
# 31582                           NaN         Bernhardsen     49945       Fia
#
#                      BirthDate Gender  ... Country RequiresGuardian  \
# 0      1935-03-04 00:00:00.000      M  ...     no               0.0
# 1      1930-11-05 00:00:00.000      M  ...     no               0.0
# 2      1960-03-10 00:00:00.000      M  ...     no               0.0
# 3      1942-10-19 00:00:00.000      M  ...     no               0.0
# 4      1931-01-22 00:00:00.000      K  ...     no               0.0
# ...                        ...    ...  ...     ...              ...
# 31578  2009-09-01 00:00:00.000      M  ...     no               0.0
# 31579  2021-05-28 00:00:00.000      M  ...     us               0.0
# 31580  2021-06-22 00:00:00.000      K  ...     us               0.0
# 31581  2021-02-23 00:00:00.000      K  ...     no               0.0
# 31582  2018-05-29 00:00:00.000      K  ...     no               0.0
#
#       CountryName SecondGuardianID SourceOrganizationCountry  \
# 0           Norge              0.0                        no
# 1           Norge              0.0                        no
# 2           Norge              0.0                        no
# 3           Norge              0.0                        no
# 4           Norge              0.0                        no
# ...           ...              ...                       ...
# 31578       Norge              0.0                        no
# 31579         USA          43192.0                        us
# 31580         USA              0.0                        us
# 31581       Norge          23733.0                        no
# 31582       Norge          49946.0                        no
#
#        SourceOrganizationCountryName  SourceOrganizationCountryNameEn  \
# 0                              Norge                           Norway
# 1                              Norge                           Norway
# 2                              Norge                           Norway
# 3                              Norge                           Norway
# 4                              Norge                           Norway
# ...                              ...                              ...
# 31578                          Norge                           Norway
# 31579                            USA                              USA
# 31580                            USA                              USA
# 31581                          Norge                           Norway
# 31582                          Norge                           Norway
#
#              City PostalCode  PersonNumber
# 0          HORTEN       3188   04033542734
# 1          HORTEN       3189   05113045541
# 2          HORTEN       3187   10036044174
# 3           BORRE       3184   19104239598
# 4          HORTEN       3189   22013141618
# ...           ...        ...           ...
# 31578         NaN        NaN   01090983349
# 31579       Cable      43009           NaN
# 31580      Urbana      43078           NaN
# 31581       Hølen       1550           NaN
# 31582  Klokkarvik       5378           NaN
#
# [31583 rows x 30 columns]

# %%
registrations
# Out:
#        RegistrationId   UserId  ActivityId  SelfRegistered Comments  \
# 0              333755  16505.0     25722.0               1      NaN
# 1              349958  15855.0     27089.0               0      NaN
# 2              349959  13501.0     27089.0               0      NaN
# 3              349960  13495.0     27089.0               0      NaN
# 4              349961  13500.0     27089.0               0      NaN
# ...               ...      ...         ...             ...      ...
# 24969         1528825  11968.0    129155.0               1      NaN
# 24970         1528826  11969.0    129155.0               1      NaN
# 24971         1528827  11970.0    129155.0               1      NaN
# 24972         1528828  11971.0    129155.0               1      NaN
# 24973         1528829  11972.0    129155.0               1      NaN
#
#                   RegistrationDate  CreditedTeamId  IsReserve  \
# 0      2012-02-01 22:39:07.7670000             NaN        NaN
# 1      2012-02-29 00:00:00.0000000             NaN        NaN
# 2      2012-02-29 00:00:00.0000000             NaN        NaN
# 3      2012-02-29 00:00:00.0000000             NaN        NaN
# 4      2012-02-29 00:00:00.0000000             NaN        NaN
# ...                            ...             ...        ...
# 24969  2015-04-29 11:24:14.7272697             NaN        NaN
# 24970  2015-04-29 11:24:14.7301995             NaN        NaN
# 24971  2015-04-29 11:24:14.7341059             NaN        NaN
# 24972  2015-04-29 11:24:14.7370357             NaN        NaN
# 24973  2015-04-29 11:24:14.7399655             NaN        NaN
#
#        LastReserveNotification  LockedReserveStatus  ...  \
# 0                          NaN                  NaN  ...
# 1                          NaN                  NaN  ...
# 2                          NaN                  NaN  ...
# 3                          NaN                  NaN  ...
# 4                          NaN                  NaN  ...
# ...                        ...                  ...  ...
# 24969                      NaN                  NaN  ...
# 24970                      NaN                  NaN  ...
# 24971                      NaN                  NaN  ...
# 24972                      NaN                  NaN  ...
# 24973                      NaN                  NaN  ...
#
#                      LastChanged.1 UseDiscount.1  UseFoodCoupon.1  \
# 0                              NaN           NaN              NaN
# 1                              NaN           NaN              NaN
# 2                              NaN           NaN              NaN
# 3                              NaN           NaN              NaN
# 4                              NaN           NaN              NaN
# ...                            ...           ...              ...
# 24969  2015-04-29 11:25:01.1089335           NaN              NaN
# 24970  2015-04-29 11:25:01.1157697           NaN              NaN
# 24971  2015-04-29 11:25:01.1226059           NaN              NaN
# 24972  2015-04-29 11:25:01.1304187           NaN              NaN
# 24973  2015-04-29 11:25:01.1899913           NaN              NaN
#
#                          Arrival.1                  Departure.1 Responsible.1  \
# 0                              NaN                          NaN           NaN
# 1                              NaN                          NaN           NaN
# 2                              NaN                          NaN           NaN
# 3                              NaN                          NaN           NaN
# 4                              NaN                          NaN           NaN
# ...                            ...                          ...           ...
# 24969  2015-07-04 20:00:00.0000000  2015-07-17 20:00:00.0000000           NaN
# 24970  2015-07-04 20:00:00.0000000  2015-07-17 20:00:00.0000000           NaN
# 24971  2015-07-04 20:00:00.0000000  2015-07-17 20:00:00.0000000           NaN
# 24972  2015-07-04 20:00:00.0000000  2015-07-17 20:00:00.0000000           NaN
# 24973  2015-07-04 20:00:00.0000000  2015-07-17 20:00:00.0000000           NaN
#
#        ForceInRegistrationPeriod.1  Confirmed.1  GroupId.1  Id.1
# 0                              NaN          NaN        NaN     0
# 1                              NaN          NaN        NaN     0
# 2                              NaN          NaN        NaN     0
# 3                              NaN          NaN        NaN     0
# 4                              NaN          NaN        NaN     0
# ...                            ...          ...        ...   ...
# 24969                          NaN          NaN        NaN     0
# 24970                          NaN          NaN        NaN     0
# 24971                          NaN          NaN        NaN     0
# 24972                          NaN          NaN        NaN     0
# 24973                          NaN          NaN        NaN     0
#
# [24974 rows x 41 columns]

# %%
registrationsIn2021 = registrations[registrations['RegistrationDate'] > '2015-01-01']

# %%
registrationsIn2021[['RegistrationId','ActivityId', 'UserId']]
users[['UserId']]
# Out:
#        UserId
# 0       10001
# 1       10002
# 2       10003
# 3       10005
# 4       10006
# ...       ...
# 31578   55027
# 31579   55028
# 31580   55029
# 31581   55030
# 31582   55031
#
# [31583 rows x 1 columns]
