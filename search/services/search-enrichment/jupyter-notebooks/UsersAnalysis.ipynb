# %%
import numpy as np
import pandas as pd

users = pd.read_csv("../data/users.csv")

# %%
users
# Out:
#        UserId  SourceOrganizationId                      Address1 Address2  \
# 0       10001                  42.0            Joh. Solliesgt 36B      NaN
# 1       10002                  42.0                  Knutsrødv 31      NaN
# 2       10003                  42.0                  Rustadgt. 53      NaN
# 3       10005                  42.0  Inger Alver Gløersens vei 69      NaN
# 4       10006                  42.0              Apenesbakken 18b      NaN
# ...       ...                   ...                           ...      ...
# 31578   55027                  78.0                           NaN      NaN
# 31579   55028                 102.0              6997 e us hwy 36      NaN
# 31580   55029                 102.0             1559 S Dugan Road      NaN
# 31581   55030                  69.0                Molvikveien 64      NaN
# 31582   55031                   7.0          Nedre Fiksnesvika 10      NaN
#
# ...

# %%
usersGroupByCountry = users.groupby(by=["SourceOrganizationCountryNameEn"], dropna=False).count().reset_index();

# %%
usersGroupByCountry.apply(lambda x : x).sort_values('UserId', ascending = 'true')
# Out:
#    SourceOrganizationCountryNameEn  UserId  SourceOrganizationId  Address1  \
# 32                          Kuwait       1                     1         0
# 56                      Yugoslavia       1                     1         0
# 24                          Greece       1                     1         1
# 57                             NaN       2                     1         1
# 53                          Uganda       7                     7         4
# 17                           Egypt       7                     7         2
# 20                        Ethiopia      10                    10         9
# 28                       Indonesia      12                    12         9
# 14                         Croatia      13                    13         6
# 29                          Israel      14                    14        13
# 6                          Belgium      14                    14         3
# ...

# %%
usersGroupByBirthDate = users.groupby(by=["BirthDate"], dropna=False).count().reset_index();

# %%
usersGroupByBirthDate
# Out:
#                      BirthDate  UserId  SourceOrganizationId  Address1  \
# 0      1800-01-01 00:00:00.000      19                    19         3
# 1      1900-01-01 00:00:00.000      16                    16         0
# 2      1900-04-01 00:00:00.000       6                     6         3
# 3      1901-01-01 00:00:00.000       3                     3         0
# 4      1902-07-16 00:00:00.000       1                     1         1
# ...                        ...     ...                   ...       ...
# 17575  2021-06-13 00:00:00.000       1                     1         1
# 17576  2021-06-22 00:00:00.000       1                     1         1
# 17577  2021-06-24 00:00:00.000       1                     1         1
# 17578  2021-06-27 00:00:00.000       1                     1         1
# 17579                      NaN       3                     3         0
#
#        Address2  Email  LastName  FamilyId  FirstName  Gender  ...  Country  \
# ...

# %%
import matplotlib.pyplot as plt

corr = plt.plot(users["UserId"], users["SourceOrganizationId"])
