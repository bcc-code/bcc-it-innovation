# %%
import numpy as np
import pandas as pd

# %%
users = pd.read_csv("data/users.csv")

# %%
users
# Out:
#        UserId  SourceOrganizationId                      Address1 Address2  \
# 0       10001                  42.0            Joh. Solliesgt 36B      NaN
# 1       10002                  42.0                  Knutsrødv 31      NaN
# 2       10003                  42.0                  Rustadgt. 53      NaN
# 3       10005                  42.0  Inger Alver Gløersens vei 69      NaN
# 4       10006                  42.0              Apenesbakken 18b      NaN
# ...       ...                   ...                           ...      ...
# 31578   55027                  78.0                           NaN      NaN
# 31579   55028                 102.0              6997 e us hwy 36      NaN
# 31580   55029                 102.0             1559 S Dugan Road      NaN
# 31581   55030                  69.0                Molvikveien 64      NaN
# 31582   55031                   7.0          Nedre Fiksnesvika 10      NaN
#
# ...

# %%
usersGroupByCountry = users.groupby(by=["SourceOrganizationCountryNameEn"], dropna=False)

# %%
usersGroupByCountry

# %%
usersGroupByCountry = users.groupby(by=["SourceOrganizationCountryNameEn"], dropna=False)
usersGroupByCountry.first()
# Out:
#                                  UserId  SourceOrganizationId  \
# SourceOrganizationCountryNameEn
# Albania                           18676                 505.0
# Argentina                         18266                  72.0
# Aruba                             22515                 165.0
# Australia                         10706                  92.0
# Austria                           10818                  26.0
# Belarus                           23376                 369.0
# Belgium                           12215                   6.0
# Brasil                            11248                 469.0
# Bulgaria                          22673                 402.0
# Cameroon                          21854                  46.0
# Canada                            10766                 106.0
# Chile                             14026                 399.0
# China                             17818                 172.0
# Congo                             45345                 448.0
# ...

# %%
usersGroupByCountry.apply(lambda x : x)
# Out:
#        UserId  SourceOrganizationId                      Address1 Address2  \
# 0       10001                  42.0            Joh. Solliesgt 36B      NaN
# 1       10002                  42.0                  Knutsrødv 31      NaN
# 2       10003                  42.0                  Rustadgt. 53      NaN
# 3       10005                  42.0  Inger Alver Gløersens vei 69      NaN
# 4       10006                  42.0              Apenesbakken 18b      NaN
# ...       ...                   ...                           ...      ...
# 31578   55027                  78.0                           NaN      NaN
# 31579   55028                 102.0              6997 e us hwy 36      NaN
# 31580   55029                 102.0             1559 S Dugan Road      NaN
# 31581   55030                  69.0                Molvikveien 64      NaN
# 31582   55031                   7.0          Nedre Fiksnesvika 10      NaN
#
# ...

# %%
usersGroupByCountry = users.groupby(by=["SourceOrganizationCountryNameEn"], dropna=False).count().reset_index();

# %%
usersGroupByCountry
# Out:
#    SourceOrganizationCountryNameEn  UserId  SourceOrganizationId  Address1  \
# 0                          Albania     300                   300       137
# 1                        Argentina     135                   135        72
# 2                            Aruba      38                    38        35
# 3                        Australia     382                   382       341
# 4                          Austria     357                   357       284
# 5                          Belarus      16                    16        11
# 6                          Belgium      14                    14         3
# 7                           Brasil     309                   309       165
# 8                         Bulgaria     112                   112        41
# 9                         Cameroon     662                   662       131
# 10                          Canada    1025                  1025       829
# ...
